# %% [markdown]
# <a href="https://colab.research.google.com/github/pawan-rai02/pytorch/blob/main/01_tensors_in_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# 2.11.0+cpu
# False
# None
